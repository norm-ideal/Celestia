# %% [markdown]
# <a href="https://colab.research.google.com/github/norm-ideal/Celestia/blob/master/Copy_of_20230704DeepFace_dist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 73.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.9 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=d10b36ff86c2a72c3d9a10223293698ac6995a5c8d48da2db12074628d24b0b9
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import pandas as pd

from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
# !wget -O img1.jpg https://www.tama.ac.jp/guide/teacher/img/000006tate.jpg
# !wget -O img2.jpg http://tgs.tama.ac.jp/renew/wp-content/uploads/2014/06/idehara-norimichi.jpg
# !wget -O img3.jpg https://www.tama.ac.jp/guide/teacher/img/kubota_takafumi.jpg
# !wget -O img4.jpg https://styly.cc/wp-content/uploads/2023/04/6-IMG_3306.jpg
img1 = cv2.imread('img1.jpg')
img2 = cv2.imread('img2.jpg')
img3 = cv2.imread('img3.jpg')
img4 = cv2.imread('img4.jpg')
# Out:
# --2023-07-04 07:37:25--  https://www.tama.ac.jp/guide/teacher/img/000006tate.jpg
# Resolving www.tama.ac.jp (www.tama.ac.jp)... 183.181.89.70
# Connecting to www.tama.ac.jp (www.tama.ac.jp)|183.181.89.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19509 (19K) [image/jpeg]
# Saving to: ‘img1.jpg’
#
# img1.jpg            100%[===================>]  19.05K  --.-KB/s    in 0s
#
# 2023-07-04 07:37:26 (149 MB/s) - ‘img1.jpg’ saved [19509/19509]
#
# --2023-07-04 07:37:26--  http://tgs.tama.ac.jp/renew/wp-content/uploads/2014/06/idehara-norimichi.jpg
# Resolving tgs.tama.ac.jp (tgs.tama.ac.jp)... 202.229.135.94
# Connecting to tgs.tama.ac.jp (tgs.tama.ac.jp)|202.229.135.94|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11269 (11K) [image/jpeg]
# Saving to: ‘img2.jpg’
#
# img2.jpg            100%[===================>]  11.00K  --.-KB/s    in 0s
#
# 2023-07-04 07:37:27 (183 MB/s) - ‘img2.jpg’ saved [11269/11269]
#
# ...

# %%
plt.imshow(img1[:,:,::-1])

# %%
DeepFace.analyze(img1, actions = ["age", "gender", "emotion", "race"])
# Out:
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# facial_expression_model_weights.h5 will be downloaded...
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 131MB/s]
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# age_model_weights.h5 will be downloaded...
# 100%|██████████| 539M/539M [00:03<00:00, 160MB/s]
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# gender_model_weights.h5 will be downloaded...
# 100%|██████████| 537M/537M [00:02<00:00, 255MB/s]
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# ...

# %%
"""
orig = cv2.imread("img4.jpg")

x = resp["facial_areas"]["img2"]["x"]
y = resp["facial_areas"]["img2"]["y"]
w = resp["facial_areas"]["img2"]["w"]
h = resp["facial_areas"]["img2"]["h"]

#顔を四角で囲む
img = cv2.rectangle(orig,
  pt1=(x, y),
  pt2=(x+w, y+h),
  color=(0, 255, 0),
  thickness=2,
  lineType=cv2.LINE_4,
  shift=0)

show_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(show_img)
"""
